# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataframe = pd.read_csv("affirmativeaction_ucsc_ucsb_ucsd.csv")

dataframe
# Out:
#     College  Year  Other/Unknown Applied  International Applied  \
# 0      UCSC  2019                 1390.0                 7762.0
# 1      UCSC  2018                 1622.0                 7027.0
# 2      UCSC  2017                 1363.0                 6558.0
# 3      UCSC  2016                 1332.0                 5623.0
# 4      UCSC  2015                 1351.0                 4597.0
# ..      ...   ...                    ...                    ...
# 115    UCLA  2004                 3730.0                 1265.0
# 116    UCLA  2003                 4213.0                 1244.0
# 117    UCLA  2002                 3569.0                 1295.0
# 118    UCLA  2001                 3746.0                 1573.0
# 119    UCLA  2000                 3402.0                 1292.0
#
#      White Applied  Asian/Pacific Islander Applied  American Indian Applied  \
# 0          12181.0                         15279.0                    237.0
# ...

# %%
UCSCdata = dataframe[dataframe["College"] == "UCSC"]

# %%
AmericanIndianAdmitted = list(UCSCdata["American Indian Admitted"])
AmericanIndianApplied = list(UCSCdata["American Indian Applied"])

FirstGPAAdmitted = list(UCSCdata["4.20 and Above Admitted"])
FirstGPAApplied = list(UCSCdata["4.20 and Above Applied"])

SecondGPAAdmitted = list(UCSCdata["3.80 - 4.19 Admitted"])
SecondGPAApplied = list(UCSCdata["3.80 - 4.19 Applied"])

ThirdGPAAdmitted = list(UCSCdata["3.40 - 3.79 Admitted"])
ThirdGPAApplied = list(UCSCdata["3.40 - 3.79 Applied"])

FourthGPAAdmitted = list(UCSCdata["3.00 - 3.39 Admitted"])
FourthGPAApplied = list(UCSCdata["3.00 - 3.39 Applied"])

FifthGPAAdmitted = list(UCSCdata["0.00 - 2.99 Admitted"])
FifthGPAApplied = list(UCSCdata["0.00 - 2.99 Applied"])

AmericanIndianAdmitted = AmericanIndianAdmitted[::-1]
AmericanIndianApplied = AmericanIndianApplied[::-1]

FirstGPAAdmittedReversed = FirstGPAAdmitted[::-1]
FirstGPAAppliedReversed = FirstGPAApplied[::-1]

SecondGPAAdmittedReversed = SecondGPAAdmitted[::-1]
SecondGPAAppliedReversed = SecondGPAApplied[::-1]

ThirdGPAAdmittedReversed = ThirdGPAAdmitted[::-1]
ThirdGPAAppliedReversed = ThirdGPAApplied[::-1]

FourthGPAAdmittedReversed = FourthGPAAdmitted[::-1]
FourthGPAAppliedReversed = FourthGPAApplied[::-1]

FifthGPAAdmittedReversed = FifthGPAAdmitted[::-1]
FifthGPAAppliedReversed = FifthGPAApplied[::-1]



percentAmericanIndianAdmitted = []

firstGPAPercentage = []
secondGPAPercentage = []
thirdGPAPercentage = []
fourthGPAPercentage = []
fifthGPAPercentage = []

averageGPA = []

for i in range(0, 20, 1):
    total = FirstGPAAppliedReversed[i] + SecondGPAAppliedReversed[i] + ThirdGPAAppliedReversed[i] + FourthGPAAppliedReversed[i] + FifthGPAAppliedReversed[i]
    average = (float(FirstGPAAppliedReversed[i]) * 4.2 + float(SecondGPAAppliedReversed[i]) * 4.0 + float(ThirdGPAAppliedReversed[i]) * 3.6 + float(FourthGPAAppliedReversed[i]) * 3.2 + float(FifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    averageGPA.append(average)
    
    percentage = AmericanIndianAdmitted[i] / AmericanIndianApplied[i]
    percentAmericanIndianAdmitted.append(percentage)
    
    firstGPAPercentage.append(FirstGPAAdmittedReversed[i]/FirstGPAAppliedReversed[i])
    secondGPAPercentage.append(SecondGPAAdmittedReversed[i]/SecondGPAAppliedReversed[i])
    thirdGPAPercentage.append(ThirdGPAAdmittedReversed[i]/ThirdGPAAppliedReversed[i])
    fourthGPAPercentage.append(FourthGPAAdmittedReversed[i]/FourthGPAAppliedReversed[i])
    fifthGPAPercentage.append(FifthGPAAdmittedReversed[i]/FifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

percentageAmericanAdmittedArray = np.array(percentAmericanIndianAdmitted)
FirstAmericanAdmittedArray = np.array(firstGPAPercentage)
SecondAmericanAdmittedArray = np.array(secondGPAPercentage)
ThirdAmericanAdmittedArray = np.array(thirdGPAPercentage)
FourthAmericanAdmittedArray = np.array(fourthGPAPercentage)
FifthAmericanAdmittedArray = np.array(fifthGPAPercentage)

AverageGPAArray = np.array(averageGPA)

    
plt.plot(years, percentageAmericanAdmittedArray, color='blue', label='Percentage American Indian Admitted')

#plt.plot(years, FirstAmericanAdmittedArray, color='green', label='4.20 and Above Admitted')
#plt.plot(years, SecondAmericanAdmittedArray, color='red', label='3.80 - 4.19 Admitted')
#plt.plot(years, ThirdAmericanAdmittedArray, color='pink', label='3.40 - 3.79 Admitted')
#plt.plot(years, FourthAmericanAdmittedArray, color='purple', label='3.00 - 3.39 Admitted')
#plt.plot(years, FifthAmericanAdmittedArray, color='orange', label='0.00 - 2.99 Admitted')


x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()
# Out:
# []

# %%
plt.plot(years, AverageGPAArray, color='red', label='AverageGPA')

# %%
UCSDdata = dataframe[dataframe["College"] == "UCSD"]

# %%
# SDOtherUnknownAdmitted/Applied
SDOtherUnknownAdmitted = list(UCSDdata["Other/Unknown Admitted"])
SDOtherUnknownApplied = list(UCSDdata["Other/Unknown Applied"])

SDFirstGPAAdmitted = list(UCSDdata["4.20 and Above Admitted"])
SDFirstGPAApplied = list(UCSDdata["4.20 and Above Applied"])

SDSecondGPAAdmitted = list(UCSDdata["3.80 - 4.19 Admitted"])
SDSecondGPAApplied = list(UCSDdata["3.80 - 4.19 Applied"])

SDThirdGPAAdmitted = list(UCSDdata["3.40 - 3.79 Admitted"])
SDThirdGPAApplied = list(UCSDdata["3.40 - 3.79 Applied"])

SDFourthGPAAdmitted = list(UCSDdata["3.00 - 3.39 Admitted"])
SDFourthGPAApplied = list(UCSDdata["3.00 - 3.39 Applied"])

SDFifthGPAAdmitted = list(UCSDdata["0.00 - 2.99 Admitted"])
SDFifthGPAApplied = list(UCSDdata["0.00 - 2.99 Applied"])

SDOtherUnknownAdmitted = SDOtherUnknownAdmitted[::-1]
SDOtherUnknownApplied = SDOtherUnknownApplied[::-1]

SDFirstGPAAdmittedReversed = SDFirstGPAAdmitted[::-1]
SDFirstGPAAppliedReversed = SDFirstGPAApplied[::-1]

SDSecondGPAAdmittedReversed = SDSecondGPAAdmitted[::-1]
SDSecondGPAAppliedReversed = SDSecondGPAApplied[::-1]

SDThirdGPAAdmittedReversed = SDThirdGPAAdmitted[::-1]
SDThirdGPAAppliedReversed = SDThirdGPAApplied[::-1]

SDFourthGPAAdmittedReversed = SDFourthGPAAdmitted[::-1]
SDFourthGPAAppliedReversed = SDFourthGPAApplied[::-1]

SDFifthGPAAdmittedReversed = SDFifthGPAAdmitted[::-1]
SDFifthGPAAppliedReversed = SDFifthGPAApplied[::-1]

SDpercentOtherUnknownAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

#for i in range(0, 20, 1):
 #   total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
  #  average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
   # SDaverageGPA.append(average)
    
    #percentage = SDOtherUnknownAdmitted[i] / SDOtherUnknownApplied[i]
    #SDpercentOtherUnknownAdmitted.append(percentage)
    
    #SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    #SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    #SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    #SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    #SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

#years = []
#numYear = 2000
#for i in range(0, 20, 1):
 #   years.append(numYear)
  #  numYear += 1

#SDpercentageOtherUnknownAdmittedArray = np.array(SDpercentOtherUnknownAdmitted)
#FirstAmericanAdmittedArray = np.array(firstGPAPercentage)
#SecondAmericanAdmittedArray = np.array(secondGPAPercentage)
#ThirdAmericanAdmittedArray = np.array(thirdGPAPercentage)
#FourthAmericanAdmittedArray = np.array(fourthGPAPercentage)
#FifthAmericanAdmittedArray = np.array(fifthGPAPercentage)

#SDAverageGPAArray = np.array(SDaverageGPA)

    
#plt.plot(years, SDpercentageOtherUnknownAdmittedArray, color='red', label='Percentage Other/Unknown Admitted')

#plt.plot(years, FirstAmericanAdmittedArray, color='green', label='4.20 and Above Admitted')
#plt.plot(years, SecondAmericanAdmittedArray, color='red', label='3.80 - 4.19 Admitted')
#plt.plot(years, ThirdAmericanAdmittedArray, color='pink', label='3.40 - 3.79 Admitted')
#plt.plot(years, FourthAmericanAdmittedArray, color='purple', label='3.00 - 3.39 Admitted')
#plt.plot(years, FifthAmericanAdmittedArray, color='orange', label='0.00 - 2.99 Admitted')


#x_label = "years"
#y_label = "admitted/applied"
#plt.xlabel(x_label)
#plt.ylabel(y_label)

#plt.legend()
#plt.plot()

# SDInternationalAdmitted/Applied
SDInternationalAdmitted = list(UCSDdata["International Admitted"])
SDInternationalApplied = list(UCSDdata["International Applied"])

SDInternationalAdmitted = SDInternationalAdmitted[::-1]
SDInternationalApplied = SDInternationalApplied[::-1]

SDpercentInternationalAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDInternationalAdmitted[i] / SDInternationalApplied[i]
    SDpercentInternationalAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageInternationalAdmittedArray = np.array(SDpercentInternationalAdmitted)

SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageInternationalAdmittedArray, color='yellow', label='Percentage International Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# SDWhiteAdmitted/Applied
SDWhiteAdmitted = list(UCSDdata["White Admitted"])
SDWhiteApplied = list(UCSDdata["White Applied"])

SDWhiteAdmitted = SDWhiteAdmitted[::-1]
SDWhiteApplied = SDWhiteApplied[::-1]

SDpercentWhiteAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDWhiteAdmitted[i] / SDWhiteApplied[i]
    SDpercentWhiteAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageWhiteAdmittedArray = np.array(SDpercentWhiteAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageWhiteAdmittedArray, color='green', label='Percentage White Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# SDAsian/PacificIslanderAdmitted/Applied
SDAsianPacificIslanderAdmitted = list(UCSDdata["Asian/Pacific Islander Admitted"])
SDAsianPacificIslanderApplied = list(UCSDdata["Asian/Pacific Islander Applied"])

SDAsianPacificIslanderAdmitted = SDAsianPacificIslanderAdmitted[::-1]
SDAsianPacificIslanderApplied = SDAsianPacificIslanderApplied[::-1]

SDpercentAsianPacificIslanderAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDAsianPacificIslanderAdmitted[i] / SDAsianPacificIslanderApplied[i]
    SDpercentAsianPacificIslanderAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageAsianPacificIslanderAdmittedArray = np.array(SDpercentAsianPacificIslanderAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageAsianPacificIslanderAdmittedArray, color='blue', label='Percentage Asian/Pacific Islander Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# SDAmericanIndianAdmitted/Applied
SDAmericanIndianAdmitted = list(UCSDdata["American Indian Admitted"])
SDAmericanIndianApplied = list(UCSDdata["American Indian Applied"])

SDAmericanIndianAdmitted = SDAmericanIndianAdmitted[::-1]
SDAmericanIndianApplied = SDAmericanIndianApplied[::-1]

SDpercentAmericanIndianAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDAmericanIndianAdmitted[i] / SDAmericanIndianApplied[i]
    SDpercentAmericanIndianAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageAmericanIndianAdmittedArray = np.array(SDpercentAmericanIndianAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageAmericanIndianAdmittedArray, color='purple', label='Percentage American Indian Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# SDAfricanAmericanAdmitted/Applied
SDAfricanAmericanAdmitted = list(UCSDdata["African American Admitted"])
SDAfricanAmericanApplied = list(UCSDdata["African American Applied"])

SDAfricanAmericanAdmitted = SDAfricanAmericanAdmitted[::-1]
SDAfricanAmericanApplied = SDAfricanAmericanApplied[::-1]

SDpercentAfricanAmericanAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDAfricanAmericanAdmitted[i] / SDAfricanAmericanApplied[i]
    SDpercentAfricanAmericanAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageAfricanAmericanAdmittedArray = np.array(SDpercentAfricanAmericanAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageAfricanAmericanAdmittedArray, color='tan', label='Percentage African American Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# SDHispanicLatinxAdmitted/Applied
SDHispanicLatinxAdmitted = list(UCSDdata["Hispanic/Latinx Admitted"])
SDHispanicLatinxApplied = list(UCSDdata["Hispanic/Latinx Applied"])

SDHispanicLatinxAdmitted = SDHispanicLatinxAdmitted[::-1]
SDHispanicLatinxApplied = SDHispanicLatinxApplied[::-1]

SDpercentHispanicLatinxAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDHispanicLatinxAdmitted[i] / SDHispanicLatinxApplied[i]
    SDpercentHispanicLatinxAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageHispanicLatinxAdmittedArray = np.array(SDpercentHispanicLatinxAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageHispanicLatinxAdmittedArray, color='grey', label='Percentage Hispanic/Latinx Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# SDMaleAdmitted/Applied
SDMaleAdmitted = list(UCSDdata["Male Admitted"])
SDMaleApplied = list(UCSDdata["Male Applied"])

SDMaleAdmitted = SDMaleAdmitted[::-1]
SDMaleApplied = SDMaleApplied[::-1]

SDpercentMaleAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDMaleAdmitted[i] / SDMaleApplied[i]
    SDpercentMaleAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageMaleAdmittedArray = np.array(SDpercentMaleAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageMaleAdmittedArray, color='red', label='Percentage Male Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# SDFemaleAdmitted/Applied
SDFemaleAdmitted = list(UCSDdata["Female Admitted"])
SDFemaleApplied = list(UCSDdata["Female Applied"])

SDFemaleAdmitted = SDFemaleAdmitted[::-1]
SDFemaleApplied = SDFemaleApplied[::-1]

SDpercentFemaleAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDFemaleAdmitted[i] / SDFemaleApplied[i]
    SDpercentFemaleAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageFemaleAdmittedArray = np.array(SDpercentFemaleAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageFemaleAdmittedArray, color='black', label='Percentage Female Admitted')
plt.rcParams["figure.figsize"] = (30,10)
x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

AmericanIndianAdmitted = list(UCSDdata["American Indian Admitted"])
AmericanIndianApplied = list(UCSDdata["American Indian Applied"])
HispanicAdmitted = list(UCSDdata["Hispanic/Latinx Admitted"])
HispanicApplied = list(UCSDdata["Hispanic/Latinx Applied"])
AfricanAmericanAdmitted = list(UCSDdata["African American Admitted"])
AfricanAmericanApplied = list(UCSDdata["African American Applied"])
AsianAdmitted = list(UCSDdata["Asian/Pacific Islander Admitted"])
AsianApplied = list(UCSDdata["Asian/Pacific Islander Applied"])
WhiteAdmitted = list(UCSDdata["White Admitted"])
WhiteApplied = list(UCSDdata["White Applied"])


# to calculate average GPAs for a given year
FirstGPAAdmitted = list(UCSDdata["4.20 and Above Admitted"])
FirstGPAApplied = list(UCSDdata["4.20 and Above Applied"])
SecondGPAAdmitted = list(UCSDdata["3.80 - 4.19 Admitted"])
SecondGPAApplied = list(UCSDdata["3.80 - 4.19 Applied"])
ThirdGPAAdmitted = list(UCSDdata["3.40 - 3.79 Admitted"])
ThirdGPAApplied = list(UCSDdata["3.40 - 3.79 Applied"])
FourthGPAAdmitted = list(UCSDdata["3.00 - 3.39 Admitted"])
FourthGPAApplied = list(UCSDdata["3.00 - 3.39 Applied"])
FifthGPAAdmitted = list(UCSDdata["0.00 - 2.99 Admitted"])
FifthGPAApplied = list(UCSDdata["0.00 - 2.99 Applied"])

# reversing ethnicities admittance 
AmericanIndianAdmitted = AmericanIndianAdmitted[::-1]
AmericanIndianApplied = AmericanIndianApplied[::-1]
HispanicAdmitted = HispanicAdmitted[::-1]
HispanicApplied = HispanicApplied[::-1]
AfricanAmericanAdmitted = AfricanAmericanAdmitted[::-1]
AfricanAmericanApplied = AfricanAmericanApplied[::-1]
AsianAdmitted = AsianAdmitted[::-1]
AsianApplied = AsianApplied[::-1]
WhiteAdmitted = WhiteAdmitted[::-1]
WhiteApplied = WhiteApplied[::-1]


# reversing GPA
FirstGPAAdmittedReversed = FirstGPAAdmitted[::-1]
FirstGPAAppliedReversed = FirstGPAApplied[::-1]
SecondGPAAdmittedReversed = SecondGPAAdmitted[::-1]
SecondGPAAppliedReversed = SecondGPAApplied[::-1]
ThirdGPAAdmittedReversed = ThirdGPAAdmitted[::-1]
ThirdGPAAppliedReversed = ThirdGPAApplied[::-1]
FourthGPAAdmittedReversed = FourthGPAAdmitted[::-1]
FourthGPAAppliedReversed = FourthGPAApplied[::-1]
FifthGPAAdmittedReversed = FifthGPAAdmitted[::-1]
FifthGPAAppliedReversed = FifthGPAApplied[::-1]


# percentage arrays for ethnicities
percentAmericanIndianAdmitted = []
percentHispanicAdmitted = []
percentAfricanAmericanAdmitted = []
percentAsianAdmitted = []
percentWhiteAdmitted = []


firstGPAPercentage = []
secondGPAPercentage = []
thirdGPAPercentage = []
fourthGPAPercentage = []
fifthGPAPercentage = []

# average GPAs 
SDaverageGPA = []

for i in range(0, 20, 1):
    total = FirstGPAAppliedReversed[i] + SecondGPAAppliedReversed[i] + ThirdGPAAppliedReversed[i] + FourthGPAAppliedReversed[i] + FifthGPAAppliedReversed[i]
    average = (FirstGPAAppliedReversed[i] * 4.2 + SecondGPAAppliedReversed[i] * 4.0 + ThirdGPAAppliedReversed[i] * 3.6 + FourthGPAAppliedReversed[i] * 3.2 + FifthGPAAppliedReversed[i] * 3.0) / total 
    averageGPA.append(average)
    
    AmericanIndianPercentage = AmericanIndianAdmitted[i] / AmericanIndianApplied[i]
    HispanicAdmittedPercentage = HispanicAdmitted[i] / HispanicApplied[i]
    AfricanAmericanPercentage = AfricanAmericanAdmitted[i] / AfricanAmericanApplied[i]
    AsianPercentage = AsianAdmitted[i] / AsianApplied[i]
    WhitePercentage = WhiteAdmitted[i] / WhiteApplied[i]
    
    percentAmericanIndianAdmitted.append(AmericanIndianPercentage)
    percentHispanicAdmitted.append(HispanicAdmittedPercentage)
    percentAfricanAmericanAdmitted.append(AfricanAmericanPercentage)
    percentAsianAdmitted.append(AsianPercentage)
    percentWhiteAdmitted.append(WhitePercentage)
    
    firstGPAPercentage.append(FirstGPAAdmittedReversed[i]/FirstGPAAppliedReversed[i])
    secondGPAPercentage.append(SecondGPAAdmittedReversed[i]/SecondGPAAppliedReversed[i])
    thirdGPAPercentage.append(ThirdGPAAdmittedReversed[i]/ThirdGPAAppliedReversed[i])
    fourthGPAPercentage.append(FourthGPAAdmittedReversed[i]/FourthGPAAppliedReversed[i])
    fifthGPAPercentage.append(FifthGPAAdmittedReversed[i]/FifthGPAAppliedReversed[i])

    

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

# Percentage Arrays of Ethnicities
percentageAmericanAdmittedArray = np.array(percentAmericanIndianAdmitted)
percentageHispanicAdmittedArray = np.array(percentHispanicAdmitted)
percentageAfricanAmericanAdmittedArray = np.array(percentAfricanAmericanAdmitted)
percentageAsianAdmittedArray = np.array(percentAsianAdmitted)
percentageWhiteAdmittedArray = np.array(percentWhiteAdmitted)


# just for GPAs
FirstAmericanAdmittedArray = np.array(firstGPAPercentage)
SecondAmericanAdmittedArray = np.array(secondGPAPercentage)
ThirdAmericanAdmittedArray = np.array(thirdGPAPercentage)
FourthAmericanAdmittedArray = np.array(fourthGPAPercentage)
FifthAmericanAdmittedArray = np.array(fifthGPAPercentage)

SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, percentageAmericanAdmittedArray, color='blue', label='Percentage American Indian Admitted')
plt.plot(years, percentageHispanicAdmittedArray, color='red', label='Percentage Hispanic Admitted')
plt.plot(years, percentageAfricanAmericanAdmittedArray, color='green', label='Percentage African American Admitted')

    
for i in range(0, SDAverageGPAArray.size, 2):
    print(years[i], " to: ", years[i+1])
    
    
    differenceAdmittedAmericanIndian = percentageAmericanAdmittedArray[i+1] - percentageAmericanAdmittedArray[i]
    differenceAdmittedHispanic = percentageHispanicAdmittedArray[i+1] - percentageHispanicAdmittedArray[i]
    differenceAdmittedAfricanAmerican = percentageAfricanAmericanAdmittedArray[i+1] - percentageAfricanAmericanAdmittedArray[i]
    differenceAsian = percentageAsianAdmittedArray[i+1] - percentageAsianAdmittedArray[i]
    differenceWhite = percentageWhiteAdmittedArray[i+1] - percentageWhiteAdmittedArray[i]

    
    
    differenceGPA = SDAverageGPAArray[i+1]/4.2 - SDAverageGPAArray[i]/4.2
#    print("Comparing: ", AverageGPAArray[i+1], "to: ", AverageGPAArray[i], " difference: ", differenceGPA)
    roundedAdmittedAmericanIndian = int(differenceAdmittedAmericanIndian * 1000) / 1000 * 100
    roundedAdmittedHispanic = int(differenceAdmittedHispanic * 1000) / 1000 * 100
    roundedAdmittedAfricanAmerican = int(differenceAdmittedAfricanAmerican * 1000) / 1000 * 100 
    roundedAdmittedAsian = int(differenceAsian * 1000) / 1000 * 100
    roundedAdmittedWhite = int(differenceWhite * 1000) / 1000 * 100
    
    
    
    roundedGPA = int(differenceGPA * 1000) / 1000 * 100
    print("GPA increase/decrease: " + str(roundedGPA))
    print ("Admitted American Indian: " + str(roundedAdmittedAmericanIndian) + "%")
    print ("Admitted Hispanic: " + str(roundedAdmittedHispanic) + "%")
    print ("Admitted African American: " + str(roundedAdmittedAfricanAmerican) + "%")
    print ("Admitted Asian: " + str(roundedAdmittedAsian) + "%")
    print ("Admitted White: " + str(roundedAdmittedWhite) + "%")

    

    print("")
    
print("size: ", SDAverageGPAArray.size)
#plt.plot(years, FirstAmericanAdmittedArray, color='green', label='4.20 and Above Admitted')
#plt.plot(years, SecondAmericanAdmittedArray, color='red', label='3.80 - 4.19 Admitted')
#plt.plot(years, ThirdAmericanAdmittedArray, color='pink', label='3.40 - 3.79 Admitted')
#plt.plot(years, FourthAmericanAdmittedArray, color='purple', label='3.00 - 3.39 Admitted')
#plt.plot(years, FifthAmericanAdmittedArray, color='orange', label='0.00 - 2.99 Admitted')


x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label) 
plt.ylabel(y_label)

plt.legend()
plt.plot()
# Out:
# size:  0
# []

# %%
# Minorities
SDFirstGPAAdmitted = list(UCSDdata["4.20 and Above Admitted"])
SDFirstGPAApplied = list(UCSDdata["4.20 and Above Applied"])

SDSecondGPAAdmitted = list(UCSDdata["3.80 - 4.19 Admitted"])
SDSecondGPAApplied = list(UCSDdata["3.80 - 4.19 Applied"])

SDThirdGPAAdmitted = list(UCSDdata["3.40 - 3.79 Admitted"])
SDThirdGPAApplied = list(UCSDdata["3.40 - 3.79 Applied"])

SDFourthGPAAdmitted = list(UCSDdata["3.00 - 3.39 Admitted"])
SDFourthGPAApplied = list(UCSDdata["3.00 - 3.39 Applied"])

SDFifthGPAAdmitted = list(UCSDdata["0.00 - 2.99 Admitted"])
SDFifthGPAApplied = list(UCSDdata["0.00 - 2.99 Applied"])

SDFirstGPAAdmittedReversed = SDFirstGPAAdmitted[::-1]
SDFirstGPAAppliedReversed = SDFirstGPAApplied[::-1]

SDSecondGPAAdmittedReversed = SDSecondGPAAdmitted[::-1]
SDSecondGPAAppliedReversed = SDSecondGPAApplied[::-1]

SDThirdGPAAdmittedReversed = SDThirdGPAAdmitted[::-1]
SDThirdGPAAppliedReversed = SDThirdGPAApplied[::-1]

SDFourthGPAAdmittedReversed = SDFourthGPAAdmitted[::-1]
SDFourthGPAAppliedReversed = SDFourthGPAApplied[::-1]

SDFifthGPAAdmittedReversed = SDFifthGPAAdmitted[::-1]
SDFifthGPAAppliedReversed = SDFifthGPAApplied[::-1]

# SDAmericanIndianAdmitted/Applied
SDAmericanIndianAdmitted = list(UCSDdata["American Indian Admitted"])
SDAmericanIndianApplied = list(UCSDdata["American Indian Applied"])

SDAmericanIndianAdmitted = SDAmericanIndianAdmitted[::-1]
SDAmericanIndianApplied = SDAmericanIndianApplied[::-1]

SDpercentAmericanIndianAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDAmericanIndianAdmitted[i] / SDAmericanIndianApplied[i]
    SDpercentAmericanIndianAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageAmericanIndianAdmittedArray = np.array(SDpercentAmericanIndianAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageAmericanIndianAdmittedArray, color='purple', label='Percentage American Indian Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# SDAfricanAmericanAdmitted/Applied
SDAfricanAmericanAdmitted = list(UCSDdata["African American Admitted"])
SDAfricanAmericanApplied = list(UCSDdata["African American Applied"])

SDAfricanAmericanAdmitted = SDAfricanAmericanAdmitted[::-1]
SDAfricanAmericanApplied = SDAfricanAmericanApplied[::-1]

SDpercentAfricanAmericanAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDAfricanAmericanAdmitted[i] / SDAfricanAmericanApplied[i]
    SDpercentAfricanAmericanAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageAfricanAmericanAdmittedArray = np.array(SDpercentAfricanAmericanAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageAfricanAmericanAdmittedArray, color='blue', label='Percentage African American Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# SDHispanicLatinxAdmitted/Applied
SDHispanicLatinxAdmitted = list(UCSDdata["Hispanic/Latinx Admitted"])
SDHispanicLatinxApplied = list(UCSDdata["Hispanic/Latinx Applied"])

SDHispanicLatinxAdmitted = SDHispanicLatinxAdmitted[::-1]
SDHispanicLatinxApplied = SDHispanicLatinxApplied[::-1]

SDpercentHispanicLatinxAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDHispanicLatinxAdmitted[i] / SDHispanicLatinxApplied[i]
    SDpercentHispanicLatinxAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageHispanicLatinxAdmittedArray = np.array(SDpercentHispanicLatinxAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageHispanicLatinxAdmittedArray, color='green', label='Percentage Hispanic/Latinx Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.rcParams["figure.figsize"] = (15,5)

plt.legend()
plt.plot()
#plt.plot(years, SDAverageGPAArray, color='red', label='AverageGPA')
# Out:
# []

# %%
# SDWhiteAdmitted/Applied
SDWhiteAdmitted = list(UCSDdata["White Admitted"])
SDWhiteApplied = list(UCSDdata["White Applied"])

SDWhiteAdmitted = SDWhiteAdmitted[::-1]
SDWhiteApplied = SDWhiteApplied[::-1]

SDpercentWhiteAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDWhiteAdmitted[i] / SDWhiteApplied[i]
    SDpercentWhiteAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageWhiteAdmittedArray = np.array(SDpercentWhiteAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageWhiteAdmittedArray, color='green', label='Percentage White Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# SDAsian/PacificIslanderAdmitted/Applied
SDAsianPacificIslanderAdmitted = list(UCSDdata["Asian/Pacific Islander Admitted"])
SDAsianPacificIslanderApplied = list(UCSDdata["Asian/Pacific Islander Applied"])

SDAsianPacificIslanderAdmitted = SDAsianPacificIslanderAdmitted[::-1]
SDAsianPacificIslanderApplied = SDAsianPacificIslanderApplied[::-1]

SDpercentAsianPacificIslanderAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDAsianPacificIslanderAdmitted[i] / SDAsianPacificIslanderApplied[i]
    SDpercentAsianPacificIslanderAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageAsianPacificIslanderAdmittedArray = np.array(SDpercentAsianPacificIslanderAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageAsianPacificIslanderAdmittedArray, color='blue', label='Percentage Asian/Pacific Islander Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()
# Out:
# []

# %%
# SDMaleAdmitted/Applied
SDMaleAdmitted = list(UCSDdata["Male Admitted"])
SDMaleApplied = list(UCSDdata["Male Applied"])

SDMaleAdmitted = SDMaleAdmitted[::-1]
SDMaleApplied = SDMaleApplied[::-1]

SDpercentMaleAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDMaleAdmitted[i] / SDMaleApplied[i]
    SDpercentMaleAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageMaleAdmittedArray = np.array(SDpercentMaleAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageMaleAdmittedArray, color='red', label='Percentage Male Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# SDFemaleAdmitted/Applied
SDFemaleAdmitted = list(UCSDdata["Female Admitted"])
SDFemaleApplied = list(UCSDdata["Female Applied"])

SDFemaleAdmitted = SDFemaleAdmitted[::-1]
SDFemaleApplied = SDFemaleApplied[::-1]

SDpercentFemaleAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDFemaleAdmitted[i] / SDFemaleApplied[i]
    SDpercentFemaleAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageFemaleAdmittedArray = np.array(SDpercentFemaleAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageFemaleAdmittedArray, color='black', label='Percentage Female Admitted')
plt.rcParams["figure.figsize"] = (30,10)
x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()
# Out:
# []

# %%
x_label = "years"
y_label = "Average GPA"
plt.xlabel(x_label)
plt.ylabel(y_label)
plt.rcParams["figure.figsize"] = (30,10)


plt.plot(years, SDAverageGPAArray, color='blue', label='AverageGPA')

# %%
# SDInternationalAdmitted/Applied
SDInternationalAdmitted = list(UCSDdata["International Admitted"])
SDInternationalApplied = list(UCSDdata["International Applied"])

SDInternationalAdmitted = SDInternationalAdmitted[::-1]
SDInternationalApplied = SDInternationalApplied[::-1]

SDpercentInternationalAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDInternationalAdmitted[i] / SDInternationalApplied[i]
    SDpercentInternationalAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageInternationalAdmittedArray = np.array(SDpercentInternationalAdmitted)

SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageInternationalAdmittedArray, color='red', label='Percentage International Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()
plt.plot(years, SDAverageGPAArray, color='blue', label='AverageGPA')

# %%
# SDWhiteAdmitted/Applied
SDWhiteAdmitted = list(UCSDdata["White Admitted"])
SDWhiteApplied = list(UCSDdata["White Applied"])

SDWhiteAdmitted = SDWhiteAdmitted[::-1]
SDWhiteApplied = SDWhiteApplied[::-1]

SDpercentWhiteAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDWhiteAdmitted[i] / SDWhiteApplied[i]
    SDpercentWhiteAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageWhiteAdmittedArray = np.array(SDpercentWhiteAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageWhiteAdmittedArray, color='red', label='Percentage White Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()
plt.plot(years, SDAverageGPAArray, color='blue', label='AverageGPA')

# %%
# SDAsian/PacificIslanderAdmitted/Applied
SDAsianPacificIslanderAdmitted = list(UCSDdata["Asian/Pacific Islander Admitted"])
SDAsianPacificIslanderApplied = list(UCSDdata["Asian/Pacific Islander Applied"])

SDAsianPacificIslanderAdmitted = SDAsianPacificIslanderAdmitted[::-1]
SDAsianPacificIslanderApplied = SDAsianPacificIslanderApplied[::-1]

SDpercentAsianPacificIslanderAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDAsianPacificIslanderAdmitted[i] / SDAsianPacificIslanderApplied[i]
    SDpercentAsianPacificIslanderAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageAsianPacificIslanderAdmittedArray = np.array(SDpercentAsianPacificIslanderAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageAsianPacificIslanderAdmittedArray, color='red', label='Percentage Asian/Pacific Islander Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()
# Out:
# []

# %%
# SDAmericanIndianAdmitted/Applied
SDAmericanIndianAdmitted = list(UCSDdata["American Indian Admitted"])
SDAmericanIndianApplied = list(UCSDdata["American Indian Applied"])

SDAmericanIndianAdmitted = SDAmericanIndianAdmitted[::-1]
SDAmericanIndianApplied = SDAmericanIndianApplied[::-1]

SDpercentAmericanIndianAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDAmericanIndianAdmitted[i] / SDAmericanIndianApplied[i]
    SDpercentAmericanIndianAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageAmericanIndianAdmittedArray = np.array(SDpercentAmericanIndianAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageAmericanIndianAdmittedArray, color='red', label='Percentage American Indian Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()
# Out:
# []

# %%
# SDAfricanAmericanAdmitted/Applied
SDAfricanAmericanAdmitted = list(UCSDdata["African American Admitted"])
SDAfricanAmericanApplied = list(UCSDdata["African American Applied"])

SDAfricanAmericanAdmitted = SDAfricanAmericanAdmitted[::-1]
SDAfricanAmericanApplied = SDAfricanAmericanApplied[::-1]

SDpercentAfricanAmericanAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDAfricanAmericanAdmitted[i] / SDAfricanAmericanApplied[i]
    SDpercentAfricanAmericanAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageAfricanAmericanAdmittedArray = np.array(SDpercentAfricanAmericanAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageAfricanAmericanAdmittedArray, color='red', label='Percentage African American Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()
# Out:
# []

# %%
# SDHispanicLatinxAdmitted/Applied
SDHispanicLatinxAdmitted = list(UCSDdata["Hispanic/Latinx Admitted"])
SDHispanicLatinxApplied = list(UCSDdata["Hispanic/Latinx Applied"])

SDHispanicLatinxAdmitted = SDHispanicLatinxAdmitted[::-1]
SDHispanicLatinxApplied = SDHispanicLatinxApplied[::-1]

SDpercentHispanicLatinxAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDHispanicLatinxAdmitted[i] / SDHispanicLatinxApplied[i]
    SDpercentHispanicLatinxAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageHispanicLatinxAdmittedArray = np.array(SDpercentHispanicLatinxAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageHispanicLatinxAdmittedArray, color='red', label='Percentage Hispanic/Latinx Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()
# Out:
# []

# %%
# SDMaleAdmitted/Applied
SDMaleAdmitted = list(UCSDdata["Male Admitted"])
SDMaleApplied = list(UCSDdata["Male Applied"])

SDMaleAdmitted = SDMaleAdmitted[::-1]
SDMaleApplied = SDMaleApplied[::-1]

SDpercentMaleAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDMaleAdmitted[i] / SDMaleApplied[i]
    SDpercentMaleAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageMaleAdmittedArray = np.array(SDpercentMaleAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageMaleAdmittedArray, color='red', label='Percentage Male Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()
# Out:
# []

# %%
# SDFemaleAdmitted/Applied
SDFemaleAdmitted = list(UCSDdata["Female Admitted"])
SDFemaleApplied = list(UCSDdata["Female Applied"])

SDFemaleAdmitted = SDFemaleAdmitted[::-1]
SDFemaleApplied = SDFemaleApplied[::-1]

SDpercentFemaleAdmitted = []

SDfirstGPAPercentage = []
SDsecondGPAPercentage = []
SDthirdGPAPercentage = []
SDfourthGPAPercentage = []
SDfifthGPAPercentage = []

SDaverageGPA = []

for i in range(0, 20, 1):
    total = SDFirstGPAAppliedReversed[i] + SDSecondGPAAppliedReversed[i] + SDThirdGPAAppliedReversed[i] + SDFourthGPAAppliedReversed[i] + SDFifthGPAAppliedReversed[i]
    average = (float(SDFirstGPAAppliedReversed[i]) * 4.2 + float(SDSecondGPAAppliedReversed[i]) * 4.0 + float(SDThirdGPAAppliedReversed[i]) * 3.6 + float(SDFourthGPAAppliedReversed[i]) * 3.2 + float(SDFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    SDaverageGPA.append(average)
    
    percentage = SDFemaleAdmitted[i] / SDFemaleApplied[i]
    SDpercentFemaleAdmitted.append(percentage)
    
    SDfirstGPAPercentage.append(SDFirstGPAAdmittedReversed[i]/SDFirstGPAAppliedReversed[i])
    SDsecondGPAPercentage.append(SDSecondGPAAdmittedReversed[i]/SDSecondGPAAppliedReversed[i])
    SDthirdGPAPercentage.append(SDThirdGPAAdmittedReversed[i]/SDThirdGPAAppliedReversed[i])
    SDfourthGPAPercentage.append(SDFourthGPAAdmittedReversed[i]/SDFourthGPAAppliedReversed[i])
    SDfifthGPAPercentage.append(SDFifthGPAAdmittedReversed[i]/SDFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

SDpercentageFemaleAdmittedArray = np.array(SDpercentFemaleAdmitted)
SDAverageGPAArray = np.array(SDaverageGPA)

    
plt.plot(years, SDpercentageFemaleAdmittedArray, color='red', label='Percentage Female Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()
# Out:
# []

# %%
UCLAdata = dataframe[dataframe["College"] == "UCLA"]

# %%
# LAOtherUnknownAdmitted/Applied
LAOtherUnknownAdmitted = list(UCLAdata["Other/Unknown Admitted"])
LAOtherUnknownApplied = list(UCLAdata["Other/Unknown Applied"])

LAFirstGPAAdmitted = list(UCLAdata["4.20 and Above Admitted"])
LAFirstGPAApplied = list(UCLAdata["4.20 and Above Applied"])

LASecondGPAAdmitted = list(UCLAdata["3.80 - 4.19 Admitted"])
LASecondGPAApplied = list(UCLAdata["3.80 - 4.19 Applied"])

LAThirdGPAAdmitted = list(UCLAdata["3.40 - 3.79 Admitted"])
LAThirdGPAApplied = list(UCLAdata["3.40 - 3.79 Applied"])

LAFourthGPAAdmitted = list(UCLAdata["3.00 - 3.39 Admitted"])
LAFourthGPAApplied = list(UCLAdata["3.00 - 3.39 Applied"])

LAFifthGPAAdmitted = list(UCLAdata["0.00 - 2.99 Admitted"])
LAFifthGPAApplied = list(UCLAdata["0.00 - 2.99 Applied"])

LAOtherUnknownAdmitted = LAOtherUnknownAdmitted[::-1]
LAOtherUnknownApplied = LAOtherUnknownApplied[::-1]

LAFirstGPAAdmittedReversed = LAFirstGPAAdmitted[::-1]
LAFirstGPAAppliedReversed = LAFirstGPAApplied[::-1]

LASecondGPAAdmittedReversed = LASecondGPAAdmitted[::-1]
LASecondGPAAppliedReversed = LASecondGPAApplied[::-1]

LAThirdGPAAdmittedReversed = LAThirdGPAAdmitted[::-1]
LAThirdGPAAppliedReversed = LAThirdGPAApplied[::-1]

LAFourthGPAAdmittedReversed = LAFourthGPAAdmitted[::-1]
LAFourthGPAAppliedReversed = LAFourthGPAApplied[::-1]

LAFifthGPAAdmittedReversed = LAFifthGPAAdmitted[::-1]
LAFifthGPAAppliedReversed = LAFifthGPAApplied[::-1]

LApercentOtherUnknownAdmitted = []

LAfirstGPAPercentage = []
LAsecondGPAPercentage = []
LAthirdGPAPercentage = []
LAfourthGPAPercentage = []
LAfifthGPAPercentage = []

LAaverageGPA = []

for i in range(0, 20, 1):
    total = LAFirstGPAAppliedReversed[i] + LASecondGPAAppliedReversed[i] + LAThirdGPAAppliedReversed[i] + LAFourthGPAAppliedReversed[i] + LAFifthGPAAppliedReversed[i]
    average = (float(LAFirstGPAAppliedReversed[i]) * 4.2 + float(LASecondGPAAppliedReversed[i]) * 4.0 + float(LAThirdGPAAppliedReversed[i]) * 3.6 + float(LAFourthGPAAppliedReversed[i]) * 3.2 + float(LAFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    LAaverageGPA.append(average)
    
    percentage = LAOtherUnknownAdmitted[i] / LAOtherUnknownApplied[i]
    LApercentOtherUnknownAdmitted.append(percentage)
    
    LAfirstGPAPercentage.append(LAFirstGPAAdmittedReversed[i]/LAFirstGPAAppliedReversed[i])
    LAsecondGPAPercentage.append(LASecondGPAAdmittedReversed[i]/LASecondGPAAppliedReversed[i])
    LAthirdGPAPercentage.append(LAThirdGPAAdmittedReversed[i]/LAThirdGPAAppliedReversed[i])
    LAfourthGPAPercentage.append(LAFourthGPAAdmittedReversed[i]/LAFourthGPAAppliedReversed[i])
    LAfifthGPAPercentage.append(LAFifthGPAAdmittedReversed[i]/LAFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

LApercentageOtherUnknownAdmittedArray = np.array(LApercentOtherUnknownAdmitted)
#FirstAmericanAdmittedArray = np.array(firstGPAPercentage)
#SecondAmericanAdmittedArray = np.array(secondGPAPercentage)
#ThirdAmericanAdmittedArray = np.array(thirdGPAPercentage)
#FourthAmericanAdmittedArray = np.array(fourthGPAPercentage)
#FifthAmericanAdmittedArray = np.array(fifthGPAPercentage)

LAAverageGPAArray = np.array(LAaverageGPA)

    
plt.plot(years, LApercentageOtherUnknownAdmittedArray, color='red', label='Percentage Other/Unknown Admitted')

#plt.plot(years, FirstAmericanAdmittedArray, color='green', label='4.20 and Above Admitted')
#plt.plot(years, SecondAmericanAdmittedArray, color='red', label='3.80 - 4.19 Admitted')
#plt.plot(years, ThirdAmericanAdmittedArray, color='pink', label='3.40 - 3.79 Admitted')
#plt.plot(years, FourthAmericanAdmittedArray, color='purple', label='3.00 - 3.39 Admitted')
#plt.plot(years, FifthAmericanAdmittedArray, color='orange', label='0.00 - 2.99 Admitted')


x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# LAInternationalAdmitted/Applied
LAInternationalAdmitted = list(UCLAdata["International Admitted"])
LAInternationalApplied = list(UCLAdata["International Applied"])

LAInternationalAdmitted = LAInternationalAdmitted[::-1]
LAInternationalApplied = LAInternationalApplied[::-1]

LApercentInternationalAdmitted = []

LAfirstGPAPercentage = []
LAsecondGPAPercentage = []
LAthirdGPAPercentage = []
LAfourthGPAPercentage = []
LAfifthGPAPercentage = []

LAaverageGPA = []

for i in range(0, 20, 1):
    total = LAFirstGPAAppliedReversed[i] + LASecondGPAAppliedReversed[i] + LAThirdGPAAppliedReversed[i] + LAFourthGPAAppliedReversed[i] + LAFifthGPAAppliedReversed[i]
    average = (float(LAFirstGPAAppliedReversed[i]) * 4.2 + float(LASecondGPAAppliedReversed[i]) * 4.0 + float(LAThirdGPAAppliedReversed[i]) * 3.6 + float(LAFourthGPAAppliedReversed[i]) * 3.2 + float(LAFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    LAaverageGPA.append(average)
    
    percentage = LAInternationalAdmitted[i] / LAInternationalApplied[i]
    LApercentInternationalAdmitted.append(percentage)
    
    LAfirstGPAPercentage.append(LAFirstGPAAdmittedReversed[i]/LAFirstGPAAppliedReversed[i])
    LAsecondGPAPercentage.append(LASecondGPAAdmittedReversed[i]/LASecondGPAAppliedReversed[i])
    LAthirdGPAPercentage.append(LAThirdGPAAdmittedReversed[i]/LAThirdGPAAppliedReversed[i])
    LAfourthGPAPercentage.append(LAFourthGPAAdmittedReversed[i]/LAFourthGPAAppliedReversed[i])
    LAfifthGPAPercentage.append(LAFifthGPAAdmittedReversed[i]/LAFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

LApercentageInternationalAdmittedArray = np.array(LApercentInternationalAdmitted)

LAAverageGPAArray = np.array(LAaverageGPA)

    
plt.plot(years, LApercentageInternationalAdmittedArray, color='yellow', label='Percentage International Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# LAWhiteAdmitted/Applied
LAWhiteAdmitted = list(UCLAdata["White Admitted"])
LAWhiteApplied = list(UCLAdata["White Applied"])

LAWhiteAdmitted = LAWhiteAdmitted[::-1]
LAWhiteApplied = LAWhiteApplied[::-1]

LApercentWhiteAdmitted = []

LAfirstGPAPercentage = []
LAsecondGPAPercentage = []
LAthirdGPAPercentage = []
LAfourthGPAPercentage = []
LAfifthGPAPercentage = []

LAaverageGPA = []

for i in range(0, 20, 1):
    total = LAFirstGPAAppliedReversed[i] + LASecondGPAAppliedReversed[i] + LAThirdGPAAppliedReversed[i] + LAFourthGPAAppliedReversed[i] + LAFifthGPAAppliedReversed[i]
    average = (float(LAFirstGPAAppliedReversed[i]) * 4.2 + float(LASecondGPAAppliedReversed[i]) * 4.0 + float(LAThirdGPAAppliedReversed[i]) * 3.6 + float(LAFourthGPAAppliedReversed[i]) * 3.2 + float(LAFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    LAaverageGPA.append(average)
    
    percentage = LAWhiteAdmitted[i] / LAWhiteApplied[i]
    LApercentWhiteAdmitted.append(percentage)
    
    LAfirstGPAPercentage.append(LAFirstGPAAdmittedReversed[i]/LAFirstGPAAppliedReversed[i])
    LAsecondGPAPercentage.append(LASecondGPAAdmittedReversed[i]/LASecondGPAAppliedReversed[i])
    LAthirdGPAPercentage.append(LAThirdGPAAdmittedReversed[i]/LAThirdGPAAppliedReversed[i])
    LAfourthGPAPercentage.append(LAFourthGPAAdmittedReversed[i]/LAFourthGPAAppliedReversed[i])
    LAfifthGPAPercentage.append(LAFifthGPAAdmittedReversed[i]/LAFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

LApercentageWhiteAdmittedArray = np.array(LApercentWhiteAdmitted)
LAAverageGPAArray = np.array(LAaverageGPA)

    
plt.plot(years, LApercentageWhiteAdmittedArray, color='green', label='Percentage White Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# LAAsian/PacificIslanderAdmitted/Applied
LAAsianPacificIslanderAdmitted = list(UCLAdata["Asian/Pacific Islander Admitted"])
LAAsianPacificIslanderApplied = list(UCLAdata["Asian/Pacific Islander Applied"])

LAAsianPacificIslanderAdmitted = LAAsianPacificIslanderAdmitted[::-1]
LAAsianPacificIslanderApplied = LAAsianPacificIslanderApplied[::-1]

LApercentAsianPacificIslanderAdmitted = []

LAfirstGPAPercentage = []
LAsecondGPAPercentage = []
LAthirdGPAPercentage = []
LAfourthGPAPercentage = []
LAfifthGPAPercentage = []

LAaverageGPA = []

for i in range(0, 20, 1):
    total = LAFirstGPAAppliedReversed[i] + LASecondGPAAppliedReversed[i] + LAThirdGPAAppliedReversed[i] + LAFourthGPAAppliedReversed[i] + LAFifthGPAAppliedReversed[i]
    average = (float(LAFirstGPAAppliedReversed[i]) * 4.2 + float(LASecondGPAAppliedReversed[i]) * 4.0 + float(LAThirdGPAAppliedReversed[i]) * 3.6 + float(LAFourthGPAAppliedReversed[i]) * 3.2 + float(LAFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    LAaverageGPA.append(average)
    
    percentage = LAAsianPacificIslanderAdmitted[i] / LAAsianPacificIslanderApplied[i]
    LApercentAsianPacificIslanderAdmitted.append(percentage)
    
    LAfirstGPAPercentage.append(LAFirstGPAAdmittedReversed[i]/LAFirstGPAAppliedReversed[i])
    LAsecondGPAPercentage.append(LASecondGPAAdmittedReversed[i]/LASecondGPAAppliedReversed[i])
    LAthirdGPAPercentage.append(LAThirdGPAAdmittedReversed[i]/LAThirdGPAAppliedReversed[i])
    LAfourthGPAPercentage.append(LAFourthGPAAdmittedReversed[i]/LAFourthGPAAppliedReversed[i])
    LAfifthGPAPercentage.append(LAFifthGPAAdmittedReversed[i]/LAFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

LApercentageAsianPacificIslanderAdmittedArray = np.array(LApercentAsianPacificIslanderAdmitted)
LAAverageGPAArray = np.array(LAaverageGPA)

    
plt.plot(years, LApercentageAsianPacificIslanderAdmittedArray, color='blue', label='Percentage Asian/Pacific Islander Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# LAAmericanIndianAdmitted/Applied
LAAmericanIndianAdmitted = list(UCLAdata["American Indian Admitted"])
LAAmericanIndianApplied = list(UCLAdata["American Indian Applied"])

LAAmericanIndianAdmitted = LAAmericanIndianAdmitted[::-1]
LAAmericanIndianApplied = LAAmericanIndianApplied[::-1]

LApercentAmericanIndianAdmitted = []

LAfirstGPAPercentage = []
LAsecondGPAPercentage = []
LAthirdGPAPercentage = []
LAfourthGPAPercentage = []
LAfifthGPAPercentage = []

LAaverageGPA = []

for i in range(0, 20, 1):
    total = LAFirstGPAAppliedReversed[i] + LASecondGPAAppliedReversed[i] + LAThirdGPAAppliedReversed[i] + LAFourthGPAAppliedReversed[i] + LAFifthGPAAppliedReversed[i]
    average = (float(LAFirstGPAAppliedReversed[i]) * 4.2 + float(LASecondGPAAppliedReversed[i]) * 4.0 + float(LAThirdGPAAppliedReversed[i]) * 3.6 + float(LAFourthGPAAppliedReversed[i]) * 3.2 + float(LAFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    LAaverageGPA.append(average)
    
    percentage = LAAmericanIndianAdmitted[i] / LAAmericanIndianApplied[i]
    LApercentAmericanIndianAdmitted.append(percentage)
    
    LAfirstGPAPercentage.append(LAFirstGPAAdmittedReversed[i]/LAFirstGPAAppliedReversed[i])
    LAsecondGPAPercentage.append(LASecondGPAAdmittedReversed[i]/LASecondGPAAppliedReversed[i])
    LAthirdGPAPercentage.append(LAThirdGPAAdmittedReversed[i]/LAThirdGPAAppliedReversed[i])
    LAfourthGPAPercentage.append(LAFourthGPAAdmittedReversed[i]/LAFourthGPAAppliedReversed[i])
    LAfifthGPAPercentage.append(LAFifthGPAAdmittedReversed[i]/LAFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

LApercentageAmericanIndianAdmittedArray = np.array(LApercentAmericanIndianAdmitted)
LAAverageGPAArray = np.array(LAaverageGPA)

    
plt.plot(years, LApercentageAmericanIndianAdmittedArray, color='purple', label='Percentage American Indian Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# LAAfricanAmericanAdmitted/Applied
LAAfricanAmericanAdmitted = list(UCLAdata["African American Admitted"])
LAAfricanAmericanApplied = list(UCLAdata["African American Applied"])

LAAfricanAmericanAdmitted = LAAfricanAmericanAdmitted[::-1]
LAAfricanAmericanApplied = LAAfricanAmericanApplied[::-1]

LApercentAfricanAmericanAdmitted = []

LAfirstGPAPercentage = []
LAsecondGPAPercentage = []
LAthirdGPAPercentage = []
LAfourthGPAPercentage = []
LAfifthGPAPercentage = []

LAaverageGPA = []

for i in range(0, 20, 1):
    total = LAFirstGPAAppliedReversed[i] + LASecondGPAAppliedReversed[i] + LAThirdGPAAppliedReversed[i] + LAFourthGPAAppliedReversed[i] + LAFifthGPAAppliedReversed[i]
    average = (float(LAFirstGPAAppliedReversed[i]) * 4.2 + float(LASecondGPAAppliedReversed[i]) * 4.0 + float(LAThirdGPAAppliedReversed[i]) * 3.6 + float(LAFourthGPAAppliedReversed[i]) * 3.2 + float(LAFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    LAaverageGPA.append(average)
    
    percentage = LAAfricanAmericanAdmitted[i] / LAAfricanAmericanApplied[i]
    LApercentAfricanAmericanAdmitted.append(percentage)
    
    LAfirstGPAPercentage.append(LAFirstGPAAdmittedReversed[i]/LAFirstGPAAppliedReversed[i])
    LAsecondGPAPercentage.append(LASecondGPAAdmittedReversed[i]/LASecondGPAAppliedReversed[i])
    LAthirdGPAPercentage.append(LAThirdGPAAdmittedReversed[i]/LAThirdGPAAppliedReversed[i])
    LAfourthGPAPercentage.append(LAFourthGPAAdmittedReversed[i]/LAFourthGPAAppliedReversed[i])
    LAfifthGPAPercentage.append(LAFifthGPAAdmittedReversed[i]/LAFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

LApercentageAfricanAmericanAdmittedArray = np.array(LApercentAfricanAmericanAdmitted)
LAAverageGPAArray = np.array(LAaverageGPA)

    
plt.plot(years, LApercentageAfricanAmericanAdmittedArray, color='tan', label='Percentage African American Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# LAHispanicLatinxAdmitted/Applied
LAHispanicLatinxAdmitted = list(UCLAdata["Hispanic/Latinx Admitted"])
LAHispanicLatinxApplied = list(UCLAdata["Hispanic/Latinx Applied"])

LAHispanicLatinxAdmitted = LAHispanicLatinxAdmitted[::-1]
LAHispanicLatinxApplied = LAHispanicLatinxApplied[::-1]

LApercentHispanicLatinxAdmitted = []

LAfirstGPAPercentage = []
LAsecondGPAPercentage = []
LAthirdGPAPercentage = []
LAfourthGPAPercentage = []
LAfifthGPAPercentage = []

LAaverageGPA = []

for i in range(0, 20, 1):
    total = LAFirstGPAAppliedReversed[i] + LASecondGPAAppliedReversed[i] + LAThirdGPAAppliedReversed[i] + LAFourthGPAAppliedReversed[i] + LAFifthGPAAppliedReversed[i]
    average = (float(LAFirstGPAAppliedReversed[i]) * 4.2 + float(LASecondGPAAppliedReversed[i]) * 4.0 + float(LAThirdGPAAppliedReversed[i]) * 3.6 + float(LAFourthGPAAppliedReversed[i]) * 3.2 + float(LAFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    LAaverageGPA.append(average)
    
    percentage = LAHispanicLatinxAdmitted[i] / LAHispanicLatinxApplied[i]
    LApercentHispanicLatinxAdmitted.append(percentage)
    
    LAfirstGPAPercentage.append(LAFirstGPAAdmittedReversed[i]/LAFirstGPAAppliedReversed[i])
    LAsecondGPAPercentage.append(LASecondGPAAdmittedReversed[i]/LASecondGPAAppliedReversed[i])
    LAthirdGPAPercentage.append(LAThirdGPAAdmittedReversed[i]/LAThirdGPAAppliedReversed[i])
    LAfourthGPAPercentage.append(LAFourthGPAAdmittedReversed[i]/LAFourthGPAAppliedReversed[i])
    LAfifthGPAPercentage.append(LAFifthGPAAdmittedReversed[i]/LAFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

LApercentageHispanicLatinxAdmittedArray = np.array(LApercentHispanicLatinxAdmitted)
LAAverageGPAArray = np.array(LAaverageGPA)

    
plt.plot(years, LApercentageHispanicLatinxAdmittedArray, color='grey', label='Percentage Hispanic/Latinx Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# LAMaleAdmitted/Applied
LAMaleAdmitted = list(UCLAdata["Male Admitted"])
LAMaleApplied = list(UCLAdata["Male Applied"])

LAMaleAdmitted = LAMaleAdmitted[::-1]
LAMaleApplied = LAMaleApplied[::-1]

LApercentMaleAdmitted = []

LAfirstGPAPercentage = []
LAsecondGPAPercentage = []
LAthirdGPAPercentage = []
LAfourthGPAPercentage = []
LAfifthGPAPercentage = []

LAaverageGPA = []

for i in range(0, 20, 1):
    total = LAFirstGPAAppliedReversed[i] + LASecondGPAAppliedReversed[i] + LAThirdGPAAppliedReversed[i] + LAFourthGPAAppliedReversed[i] + LAFifthGPAAppliedReversed[i]
    average = (float(LAFirstGPAAppliedReversed[i]) * 4.2 + float(LASecondGPAAppliedReversed[i]) * 4.0 + float(LAThirdGPAAppliedReversed[i]) * 3.6 + float(LAFourthGPAAppliedReversed[i]) * 3.2 + float(LAFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    LAaverageGPA.append(average)
    
    percentage = LAMaleAdmitted[i] / LAMaleApplied[i]
    LApercentMaleAdmitted.append(percentage)
    
    LAfirstGPAPercentage.append(LAFirstGPAAdmittedReversed[i]/LAFirstGPAAppliedReversed[i])
    LAsecondGPAPercentage.append(LASecondGPAAdmittedReversed[i]/LASecondGPAAppliedReversed[i])
    LAthirdGPAPercentage.append(LAThirdGPAAdmittedReversed[i]/LAThirdGPAAppliedReversed[i])
    LAfourthGPAPercentage.append(LAFourthGPAAdmittedReversed[i]/LAFourthGPAAppliedReversed[i])
    LAfifthGPAPercentage.append(LAFifthGPAAdmittedReversed[i]/LAFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

LApercentageMaleAdmittedArray = np.array(LApercentMaleAdmitted)
LAAverageGPAArray = np.array(LAaverageGPA)

    
plt.plot(years, LApercentageMaleAdmittedArray, color='red', label='Percentage Male Admitted')

x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()

# LAFemaleAdmitted/Applied
LAFemaleAdmitted = list(UCLAdata["Female Admitted"])
LAFemaleApplied = list(UCLAdata["Female Applied"])

LAFemaleAdmitted = LAFemaleAdmitted[::-1]
LAFemaleApplied = LAFemaleApplied[::-1]

LApercentFemaleAdmitted = []

LAfirstGPAPercentage = []
LAsecondGPAPercentage = []
LAthirdGPAPercentage = []
LAfourthGPAPercentage = []
LAfifthGPAPercentage = []

LAaverageGPA = []

for i in range(0, 20, 1):
    total = LAFirstGPAAppliedReversed[i] + LASecondGPAAppliedReversed[i] + LAThirdGPAAppliedReversed[i] + LAFourthGPAAppliedReversed[i] + LAFifthGPAAppliedReversed[i]
    average = (float(LAFirstGPAAppliedReversed[i]) * 4.2 + float(LASecondGPAAppliedReversed[i]) * 4.0 + float(LAThirdGPAAppliedReversed[i]) * 3.6 + float(LAFourthGPAAppliedReversed[i]) * 3.2 + float(LAFifthGPAAppliedReversed[i]) * 3.0) / float(total) 
    LAaverageGPA.append(average)
    
    percentage = LAFemaleAdmitted[i] / LAFemaleApplied[i]
    LApercentFemaleAdmitted.append(percentage)
    
    LAfirstGPAPercentage.append(LAFirstGPAAdmittedReversed[i]/LAFirstGPAAppliedReversed[i])
    LAsecondGPAPercentage.append(LASecondGPAAdmittedReversed[i]/LASecondGPAAppliedReversed[i])
    LAthirdGPAPercentage.append(LAThirdGPAAdmittedReversed[i]/LAThirdGPAAppliedReversed[i])
    LAfourthGPAPercentage.append(LAFourthGPAAdmittedReversed[i]/LAFourthGPAAppliedReversed[i])
    LAfifthGPAPercentage.append(LAFifthGPAAdmittedReversed[i]/LAFifthGPAAppliedReversed[i])

years = []
numYear = 2000
for i in range(0, 20, 1):
    years.append(numYear)
    numYear += 1

LApercentageFemaleAdmittedArray = np.array(LApercentFemaleAdmitted)
LAAverageGPAArray = np.array(LAaverageGPA)

    
plt.plot(years, LApercentageFemaleAdmittedArray, color='black', label='Percentage Female Admitted')
plt.rcParams["figure.figsize"] = (30,10)
x_label = "years"
y_label = "admitted/applied"
plt.xlabel(x_label)
plt.ylabel(y_label)

plt.legend()
plt.plot()
# Out:
# []
